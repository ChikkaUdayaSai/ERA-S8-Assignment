# %%
import torch
import torch.optim as optim
from torchsummary import summary

from utils import get_device, train, test, show_losses, show_images, display_incorrect_images
from model import Model_S8
from dataset import get_train_test_loaders

# %%
device = get_device()
print(f'Device : {device}')
# Out:
# Device : cuda

# %%
train_loader, test_loader = get_train_test_loaders()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:12<00:00, 13195608.61it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
show_images(train_loader)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = Model_S8('group').to(device)
summary(model, input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             432
#               ReLU-2           [-1, 16, 32, 32]               0
#          GroupNorm-3           [-1, 16, 32, 32]              32
#            Dropout-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 16, 32, 32]           2,304
#               ReLU-6           [-1, 16, 32, 32]               0
#          GroupNorm-7           [-1, 16, 32, 32]              32
#            Dropout-8           [-1, 16, 32, 32]               0
#             Conv2d-9           [-1, 10, 32, 32]             160
#         MaxPool2d-10           [-1, 10, 16, 16]               0
#            Conv2d-11           [-1, 16, 16, 16]           1,440
#              ReLU-12           [-1, 16, 16, 16]               0
#         GroupNorm-13           [-1, 16, 16, 16]              32
#           Dropout-14           [-1, 16, 16, 16]               0
#            Conv2d-15           [-1, 16, 16, 16]           2,304
#              ReLU-16           [-1, 16, 16, 16]               0
#         GroupNorm-17           [-1, 16, 16, 16]              32
#           Dropout-18           [-1, 16, 16, 16]               0
#            Conv2d-19           [-1, 32, 16, 16]           4,608
#              ReLU-20           [-1, 32, 16, 16]               0
#         GroupNorm-21           [-1, 32, 16, 16]              64
#           Dropout-22           [-1, 32, 16, 16]               0
#            Conv2d-23           [-1, 16, 16, 16]             512
#         MaxPool2d-24             [-1, 16, 8, 8]               0
#            Conv2d-25             [-1, 32, 8, 8]           4,608
#              ReLU-26             [-1, 32, 8, 8]               0
#         GroupNorm-27             [-1, 32, 8, 8]              64
#           Dropout-28             [-1, 32, 8, 8]               0
#            Conv2d-29             [-1, 32, 8, 8]           9,216
#              ReLU-30             [-1, 32, 8, 8]               0
#         GroupNorm-31             [-1, 32, 8, 8]              64
#           Dropout-32             [-1, 32, 8, 8]               0
#            Conv2d-33             [-1, 32, 8, 8]           9,216
#              ReLU-34             [-1, 32, 8, 8]               0
#         GroupNorm-35             [-1, 32, 8, 8]              64
#           Dropout-36             [-1, 32, 8, 8]               0
#         AvgPool2d-37             [-1, 32, 1, 1]               0
#            Conv2d-38             [-1, 10, 1, 1]             320
# ================================================================
# Total params: 35,504
# Trainable params: 35,504
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.82
# Params size (MB): 0.14
# Estimated Total Size (MB): 1.97
# ----------------------------------------------------------------

# %%
train_losses = []
test_losses = []
train_acc = []
test_acc = []

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

EPOCHS = 20
for epoch in range(1, EPOCHS+1):
  print(f'Epoch : {epoch}')
  train(model, device, train_loader, optimizer, epoch, train_losses, train_acc)
  test(model, device, test_loader, test_losses, test_acc)
# Out:
# Epoch : 1
# Loss=1.557379961013794 Batch_id=390 Accuracy=31.70: 100%|██████████| 391/391 [00:36<00:00, 10.69it/s]
# Test set: Average loss: 1.5541, Accuracy: 4297/10000 (42.97%)
#
# Epoch : 2
# Loss=1.351531982421875 Batch_id=390 Accuracy=47.11: 100%|██████████| 391/391 [00:37<00:00, 10.49it/s]
# Test set: Average loss: 1.3546, Accuracy: 5036/10000 (50.36%)
#
# Epoch : 3
# Loss=1.2480952739715576 Batch_id=390 Accuracy=54.10: 100%|██████████| 391/391 [00:36<00:00, 10.65it/s]
# Test set: Average loss: 1.2721, Accuracy: 5504/10000 (55.04%)
#
# Epoch : 4
# Loss=1.0294511318206787 Batch_id=390 Accuracy=58.25: 100%|██████████| 391/391 [00:38<00:00, 10.14it/s]
# Test set: Average loss: 1.1804, Accuracy: 5662/10000 (56.62%)
#
# Epoch : 5
# Loss=1.1873352527618408 Batch_id=390 Accuracy=61.18: 100%|██████████| 391/391 [00:37<00:00, 10.37it/s]
# Test set: Average loss: 1.0905, Accuracy: 6084/10000 (60.84%)
#
# Epoch : 6
# Loss=0.8993903398513794 Batch_id=390 Accuracy=62.81: 100%|██████████| 391/391 [00:37<00:00, 10.48it/s]
# Test set: Average loss: 1.0183, Accuracy: 6352/10000 (63.52%)
#
# Epoch : 7
# Loss=0.9323228001594543 Batch_id=390 Accuracy=64.40: 100%|██████████| 391/391 [00:37<00:00, 10.44it/s]
# Test set: Average loss: 0.9935, Accuracy: 6473/10000 (64.73%)
#
# Epoch : 8
# Loss=0.822540283203125 Batch_id=390 Accuracy=65.47: 100%|██████████| 391/391 [00:37<00:00, 10.39it/s]
# Test set: Average loss: 0.9950, Accuracy: 6464/10000 (64.64%)
#
# Epoch : 9
# Loss=0.9262378811836243 Batch_id=390 Accuracy=66.47: 100%|██████████| 391/391 [00:38<00:00, 10.11it/s]
# Test set: Average loss: 0.9974, Accuracy: 6491/10000 (64.91%)
#
# Epoch : 10
# Loss=0.8567161560058594 Batch_id=390 Accuracy=67.83: 100%|██████████| 391/391 [00:37<00:00, 10.53it/s]
# Test set: Average loss: 0.9223, Accuracy: 6792/10000 (67.92%)
#
# Epoch : 11
# Loss=0.8871502876281738 Batch_id=390 Accuracy=68.55: 100%|██████████| 391/391 [00:37<00:00, 10.51it/s]
# Test set: Average loss: 0.9342, Accuracy: 6738/10000 (67.38%)
#
# Epoch : 12
# Loss=0.8722606897354126 Batch_id=390 Accuracy=69.67: 100%|██████████| 391/391 [00:37<00:00, 10.45it/s]
# Test set: Average loss: 0.8531, Accuracy: 6998/10000 (69.98%)
#
# Epoch : 13
# Loss=0.7960938215255737 Batch_id=390 Accuracy=70.33: 100%|██████████| 391/391 [00:37<00:00, 10.52it/s]
# Test set: Average loss: 0.8754, Accuracy: 6911/10000 (69.11%)
#
# Epoch : 14
# Loss=0.6918753981590271 Batch_id=390 Accuracy=70.75: 100%|██████████| 391/391 [00:38<00:00, 10.28it/s]
# Test set: Average loss: 0.8547, Accuracy: 7004/10000 (70.04%)
#
# Epoch : 15
# Loss=0.5431009531021118 Batch_id=390 Accuracy=71.51: 100%|██████████| 391/391 [00:36<00:00, 10.58it/s]
# Test set: Average loss: 0.8245, Accuracy: 7100/10000 (71.00%)
#
# Epoch : 16
# Loss=0.7467060685157776 Batch_id=390 Accuracy=72.08: 100%|██████████| 391/391 [00:36<00:00, 10.85it/s]
# Test set: Average loss: 0.7954, Accuracy: 7255/10000 (72.55%)
#
# Epoch : 17
# Loss=0.7604382634162903 Batch_id=390 Accuracy=72.46: 100%|██████████| 391/391 [00:36<00:00, 10.79it/s]
# Test set: Average loss: 0.7720, Accuracy: 7327/10000 (73.27%)
#
# Epoch : 18
# Loss=0.7130966782569885 Batch_id=390 Accuracy=73.12: 100%|██████████| 391/391 [00:36<00:00, 10.82it/s]
# Test set: Average loss: 0.7890, Accuracy: 7243/10000 (72.43%)
#
# Epoch : 19
# Loss=0.83832848072052 Batch_id=390 Accuracy=73.60: 100%|██████████| 391/391 [00:36<00:00, 10.74it/s]
# Test set: Average loss: 0.7554, Accuracy: 7347/10000 (73.47%)
#
# Epoch : 20
# Loss=0.5751699209213257 Batch_id=390 Accuracy=74.03: 100%|██████████| 391/391 [00:39<00:00,  9.93it/s]
# Test set: Average loss: 0.7626, Accuracy: 7356/10000 (73.56%)

# %%
cpu_train_losses = [loss.cpu().item() for loss in train_losses]
show_losses(cpu_train_losses,train_acc, test_losses,test_acc)

# %%
wrong_prediction_list = []
model.eval()
for images, labels in test_loader:
    images, labels = images.to(device), labels.to(device)
    output = model(images)
    pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
    match = pred.eq(labels.view_as(pred)).to('cpu').numpy()
    for j, i in enumerate(match):
        if(i == False):
            wrong_prediction_list.append((images[j], pred[j].item(), labels[j].item()))

# %%
display_incorrect_images(wrong_prediction_list, 10)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
